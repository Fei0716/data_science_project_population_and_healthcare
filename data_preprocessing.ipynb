# %%
import pandas as pd

# %%
# Load your data
population_df = pd.read_csv("population_state.csv")
hospital_beds_df = pd.read_csv("hospital_beds.csv")

# --- Preprocess population data ---
# Define senior age groups
senior_ages = ["60-64", "65-69", "70+", "70-74","75-79", "80-84", "85+"]  # if we want to focus on the senior citizen

pop_df = population_df[
    (population_df["sex"] == "both") &
    (population_df["age"] == "overall") &
    (population_df["ethnicity"] == "overall") 
].copy()
pop_df["population"] = (pop_df["population"] * 1000).astype(int)  # assume population is in thousands
pop_df["year"] = pd.to_datetime(pop_df["date"]).dt.year
pop_df = pop_df[["state", "year", "population"]]
# Group by state and year to sum senior population
pop_df = pop_df.groupby(["state", "year"], as_index=False)["population"].sum()


senior_pop_df = population_df[
    (population_df["sex"] == "both") &
    (population_df["age"].isin(senior_ages)) &
    (population_df["ethnicity"] == "overall") 
].copy()
senior_pop_df["population"] = (senior_pop_df["population"] * 1000).astype(int)
senior_pop_df.rename(columns={"population": "population_senior"}, inplace=True)# assume population is in thousands
senior_pop_df["year"] = pd.to_datetime(senior_pop_df["date"]).dt.year
senior_pop_df = senior_pop_df[["state", "year", "population_senior"]]
# Group by state and year to sum senior population
senior_pop_df = senior_pop_df.groupby(["state", "year"], as_index=False)["population_senior"].sum()


# --- Preprocess hospital beds data ---
beds_df = hospital_beds_df[
    (hospital_beds_df["district"] == "All Districts") &
    (hospital_beds_df["type"] == "all")
].copy()
beds_df["year"] = pd.to_datetime(beds_df["date"]).dt.year
beds_df = beds_df[["state", "year", "beds"]]

# --- Merge the datasets ---
merged_df = (
    pop_df
    .merge(beds_df, on=["state", "year"])
    .merge(senior_pop_df, on=["state", "year"])
)

# --- Calculate hospital beds per 1000 people (if focus on senior citizen only, it would be beds per 1000 senior citizen) ---
merged_df["beds_per_1000"] = round(merged_df["beds"] / (merged_df["population"] / 1000)).astype(int)
merged_df["beds_per_1000_senior"] = round(merged_df["beds"] / (merged_df["population_senior"] / 1000)).astype(int)

# View the result
print(merged_df.to_string())

merged_df.to_csv("./hospital_beds_with_population.csv", index = False)
# Out:
#                  state  year  population  beds  population_senior  beds_per_1000  beds_per_1000_senior
# 0                Johor  2015     3610300  4968             347800              1                    14
# 1                Johor  2016     3651800  5185             363800              1                    14
# 2                Johor  2017     3697000  5185             380300              1                    14
# 3                Johor  2018     3749400  5200             397700              1                    13
# 4                Johor  2019     3761200  5200             412800              1                    13
# 5                Johor  2020     4009700  5270             401800              1                    13
# 6                Johor  2021     4020000  5278             420000              1                    13
# 7                Johor  2022     4028300  5433             434700              1                    12
# 8                Kedah  2015     2096500  2653             224700              1                    12
# 9                Kedah  2016     2119700  2689             234000              1                    11
# 10               Kedah  2017     2143900  2703             243100              1                    11
# 11               Kedah  2018     2163000  2673             252500              1                    11
# 12               Kedah  2019     2173700  2711             262400              1                    10
# 13               Kedah  2020     2131400  2702             257300              1                    11
# 14               Kedah  2021     2151700  2755             270400              1                    10
# 15               Kedah  2022     2163100  2762             277200              1                    10
# 16            Kelantan  2015     1760600  2509             160300              1                    16
# 17            Kelantan  2016     1796700  2589             167100              1                    15
# 18            Kelantan  2017     1829000  2590             173600              1                    15
# 19            Kelantan  2018     1860500  2659             180500              1                    15
# 20            Kelantan  2019     1883800  2787             187299              1                    15
# 21            Kelantan  2020     1792500  2786             180500              2                    15
# 22            Kelantan  2021     1812300  2812             189600              2                    15
# 23            Kelantan  2022     1830600  2970             195200              2                    15
# 24              Melaka  2015      889000  1389              97200              2                    14
# 25              Melaka  2016      901100  1420             101400              2                    14
# 26              Melaka  2017      913100  1420             105800              2                    13
# 27              Melaka  2018      922400  1420             109900              2                    13
# 28              Melaka  2019      928400  1429             114200              2                    13
# 29              Melaka  2020      998400  1429              97200              1                    15
# 30              Melaka  2021     1004500  1439             101400              1                    14
# 31              Melaka  2022     1008600  1454             104700              1                    14
# 32     Negeri Sembilan  2015     1088800  1825             116700              2                    16
# 33     Negeri Sembilan  2016     1099300  1825             122600              2                    15
# 34     Negeri Sembilan  2017     1114000  1832             128400              2                    14
# 35     Negeri Sembilan  2018     1122900  1825             134000              2                    14
# 36     Negeri Sembilan  2019     1126200  1898             139500              2                    14
# 37     Negeri Sembilan  2020     1200000  1977             127100              2                    16
# 38     Negeri Sembilan  2021     1204200  1977             135500              2                    15
# 39     Negeri Sembilan  2022     1207900  1977             141800              2                    14
# 40              Pahang  2015     1607900  2158             153900              1                    14
# 41              Pahang  2016     1626700  2316             161000              1                    14
# 42              Pahang  2017     1647000  2391             168300              1                    14
# 43              Pahang  2018     1664700  2646             175499              2                    15
# 44              Pahang  2019     1671400  2581             182700              2                    14
# 45              Pahang  2020     1591300  2646             149900              2                    18
# 46              Pahang  2021     1601500  2611             158000              2                    17
# 47              Pahang  2022     1614300  2681             163500              2                    16
# 48               Perak  2015     2466900  5762             337300              2                    17
# 49               Perak  2016     2482100  5542             349500              2                    16
# 50               Perak  2017     2493200  5542             360500              2                    15
# 51               Perak  2018     2503500  5542             372600              2                    15
# 52               Perak  2019     2508800  5542             385200              2                    14
# 53               Perak  2020     2496000  5542             335000              2                    17
# 54               Perak  2021     2515800  5924             351500              2                    17
# 55               Perak  2022     2514400  5887             362300              2                    16
# 56              Perlis  2015      248500   408              30300              2                    13
# 57              Perlis  2016      251000   408              31300              2                    13
# 58              Perlis  2017      252000   508              32200              2                    16
# 59              Perlis  2018      253500   508              33300              2                    15
# 60              Perlis  2019      254000   508              34200              2                    15
# 61              Perlis  2020      284900   508              32900              2                    15
# 62              Perlis  2021      287600   508              34100              2                    15
# 63              Perlis  2022      289800   508              34800              2                    15
# 64        Pulau Pinang  2015     1698100  2046             196700              1                    10
# 65        Pulau Pinang  2016     1717700  2130             204700              1                    10
# 66        Pulau Pinang  2017     1744100  2065             214300              1                    10
# 67        Pulau Pinang  2018     1762800  2118             222700              1                    10
# 68        Pulau Pinang  2019     1768800  2113             230900              1                     9
# 69        Pulau Pinang  2020     1740400  2113             194900              1                    11
# 70        Pulau Pinang  2021     1740000  2133             203400              1                    10
# 71        Pulau Pinang  2022     1740900  2138             210200              1                    10
# 72               Sabah  2015     3720500  4671             184400              1                    25
# 73               Sabah  2016     3802800  4815             194900              1                    25
# 74               Sabah  2017     3855900  4877             205400              1                    24
# 75               Sabah  2018     3898400  4848             216700              1                    22
# 76               Sabah  2019     3904400  4876             227800              1                    21
# 77               Sabah  2020     3418800  5013             276700              1                    18
# 78               Sabah  2021     3412600  5023             282500              1                    18
# 79               Sabah  2022     3414900  5053             290000              1                    17
# 80             Sarawak  2015     2701500  3944             266500              1                    15
# 81             Sarawak  2016     2738700  3978             279000              1                    14
# 82             Sarawak  2017     2766300  3989             292600              1                    14
# 83             Sarawak  2018     2791700  4051             305500              1                    13
# 84             Sarawak  2019     2806000  4083             318900              1                    13
# 85             Sarawak  2020     2453700  4146             282800              2                    15
# 86             Sarawak  2021     2465600  4099             297200              2                    14
# 87             Sarawak  2022     2473500  4119             309000              2                    13
# 88            Selangor  2015     6178000  5493             440400              1                    12
# 89            Selangor  2016     6291500  5531             464800              1                    12
# 90            Selangor  2017     6380700  5471             490900              1                    11
# 91            Selangor  2018     6475000  5602             518700              1                    11
# 92            Selangor  2019     6506100  5907             546300              1                    11
# 93            Selangor  2020     6994400  6131             714400              1                     9
# 94            Selangor  2021     7014700  7159             747400              1                    10
# 95            Selangor  2022     7050300  7640             777600              1                    10
# 96          Terengganu  2015     1161000  1645              94000              1                    18
# 97          Terengganu  2016     1183400  1645              98100              1                    17
# 98          Terengganu  2017     1208000  1696             102400              1                    17
# 99          Terengganu  2018     1228300  1680             106800              1                    16
# 100         Terengganu  2019     1244500  1698             110900              1                    15
# 101         Terengganu  2020     1149400  1700             102400              1                    17
# 102         Terengganu  2021     1170700  1722             108000              1                    16
# 103         Terengganu  2022     1186600  1730             111200              1                    16
# 104  W.P. Kuala Lumpur  2015     1780400  4901             164200              3                    30
# 105  W.P. Kuala Lumpur  2016     1789700  4890             172100              3                    28
# 106  W.P. Kuala Lumpur  2017     1793200  5009             179399              3                    28
# 107  W.P. Kuala Lumpur  2018     1790000  4995             187900              3                    27
# 108  W.P. Kuala Lumpur  2019     1782500  4912             196800              3                    25
# 109  W.P. Kuala Lumpur  2020     1982100  5583             181200              3                    31
# 110  W.P. Kuala Lumpur  2021     1964000  5582             189400              3                    29
# 111  W.P. Kuala Lumpur  2022     1961200  4874             195000              2                    25
# 112        W.P. Labuan  2015       95100   122               5300              1                    23
# 113        W.P. Labuan  2016       96800   122               5900              1                    21
# 114        W.P. Labuan  2017       97600   122               6300              1                    19
# 115        W.P. Labuan  2018       99000   122               6900              1                    18
# 116        W.P. Labuan  2019       99300   122               7300              1                    17
# 117        W.P. Labuan  2020       95100   122               6700              1                    18
# 118        W.P. Labuan  2021       96000   122               7000              1                    17
# 119        W.P. Labuan  2022       96900   122               7600              1                    16
# 120     W.P. Putrajaya  2015       83000   593               2000              7                   296
# 121     W.P. Putrajaya  2016       84400   593               2400              7                   247
# 122     W.P. Putrajaya  2017       87500   654               3000              7                   218
# 123     W.P. Putrajaya  2018       97200   722               3600              7                   201
# 124     W.P. Putrajaya  2019      103700   621               4300              6                   144
# 125     W.P. Putrajaya  2020      109200   637               3000              6                   212
# 126     W.P. Putrajaya  2021      115200   637               3400              6                   187
# 127     W.P. Putrajaya  2022      117000   637               3700              5                   172

# %%
#preprocess the clinic_by_state to include the district column as well
clinic_df = pd.read_csv("clinic_by_state.csv")

# Extract the district by splitting the address and taking the second last element
clinic_df['District'] = clinic_df['Full Address'].apply(lambda x: x.split(',')[-2].strip())

# Save to a new CSV or overwrite
clinic_df.to_csv("clinic_by_state_with_district.csv", index=False)

# %%
#creating the dataset with district level for each of the healthcare facilities
clinic_df = pd.read_csv("clinic_by_state_with_district.csv")
hospital_df = pd.read_csv("hospital_by_city_state.csv")
population_df = pd.read_csv("population_district.csv")
beds_df = pd.read_csv("hospital_beds.csv")

# %%
#Preprocess population data in the district:
population_df['date'] = pd.to_datetime(population_df['date'], dayfirst=True)
# latest_year = population_df['date'].dt.year.max()
latest_year = 2022
pop_filtered = population_df[
    (population_df['sex'] == 'both') &
    (population_df['age'] == 'overall') &
    (population_df['ethnicity'] == 'overall') &
    (population_df['date'].dt.year == latest_year)
].copy()

pop_filtered['population'] = pop_filtered['population'] * 1000
pop_summary = pop_filtered[['state', 'district', 'population']]

print(pop_summary.to_string())
# Out:
#                     state                district  population
# 127680              Johor              Batu Pahat    497500.0
# 128079              Johor             Johor Bahru   1723700.0
# 128478              Johor                  Kluang    323500.0
# 128877              Johor             Kota Tinggi    224900.0
# 129276              Johor                   Kulai    329200.0
# 129675              Johor                 Mersing     79100.0
# 130074              Johor                    Muar    314000.0
# 130473              Johor                 Pontian    173600.0
# 130872              Johor                 Segamat    198200.0
# 131271              Johor                 Tangkak    164600.0
# 131670              Kedah                  Baling    144900.0
# 132069              Kedah           Bandar Baharu     44700.0
# 132468              Kedah              Kota Setar    376800.0
# 132867              Kedah              Kuala Muda    550500.0
# 133266              Kedah             Kubang Pasu    249700.0
# 133665              Kedah                   Kulim    341300.0
# 134064              Kedah                Langkawi     96400.0
# 134463              Kedah            Padang Terap     66500.0
# 134862              Kedah                 Pendang     99800.0
# 135261              Kedah              Pokok Sena     50000.0
# 135660              Kedah                     Sik     68600.0
# 136059              Kedah                     Yan     73800.0
# 136458           Kelantan                  Bachok    160700.0
# 136857           Kelantan              Gua Musang    104000.0
# 137256           Kelantan                    Jeli     56100.0
# 137655           Kelantan            Kecil Lojing     10800.0
# 138054           Kelantan              Kota Bharu    567500.0
# 138453           Kelantan              Kuala Krai    107100.0
# 138852           Kelantan                 Machang    113900.0
# 139251           Kelantan               Pasir Mas    234200.0
# 139650           Kelantan             Pasir Puteh    138900.0
# 140049           Kelantan             Tanah Merah    153700.0
# 140448           Kelantan                  Tumpat    183700.0
# 140847             Melaka              Alor Gajah    251800.0
# 141246             Melaka                   Jasin    153900.0
# 141645             Melaka           Melaka Tengah    602800.0
# 142044    Negeri Sembilan                  Jelebu     46300.0
# 142443    Negeri Sembilan                  Jempol    127600.0
# 142842    Negeri Sembilan             Kuala Pilah     70400.0
# 143241    Negeri Sembilan            Port Dickson    130100.0
# 143640    Negeri Sembilan                  Rembau     47800.0
# 144039    Negeri Sembilan                Seremban    696900.0
# 144438    Negeri Sembilan                  Tampin     88800.0
# 144837             Pahang                 Bentong    116700.0
# 145236             Pahang                    Bera     98900.0
# 145635             Pahang       Cameron Highlands     39200.0
# 146034             Pahang                Jerantut     97000.0
# 146433             Pahang                 Kuantan    557900.0
# 146832             Pahang                   Lipis     97900.0
# 147231             Pahang                   Maran    114700.0
# 147630             Pahang                   Pekan    123500.0
# 148029             Pahang                    Raub     96800.0
# 148428             Pahang                  Rompin    100400.0
# 148827             Pahang                Temerloh    171400.0
# 149226              Perak             Bagan Datuk     82300.0
# 149625              Perak           Batang Padang    125700.0
# 150024              Perak             Hilir Perak    142300.0
# 150423              Perak              Hulu Perak     95900.0
# 150822              Perak                  Kampar     98200.0
# 151221              Perak                  Kerian    167500.0
# 151620              Perak                   Kinta    895800.0
# 152019              Perak           Kuala Kangsar    176700.0
# 152418              Perak        Larut Dan Matang    272600.0
# 152817              Perak                 Manjung    249600.0
# 153216              Perak                 Muallim     78000.0
# 153615              Perak            Perak Tengah     95600.0
# 154014              Perak                  Selama     34500.0
# 154413             Perlis                  Perlis    289800.0
# 154812       Pulau Pinang              Barat Daya    239600.0
# 155211       Pulau Pinang  Seberang Perai Selatan    185500.0
# 155610       Pulau Pinang   Seberang Perai Tengah    422800.0
# 156009       Pulau Pinang    Seberang Perai Utara    341300.0
# 156408       Pulau Pinang              Timur Laut    551800.0
# 156807              Sabah                Beaufort     76100.0
# 157206              Sabah                 Beluran     76300.0
# 157605              Sabah               Kalabakan     46600.0
# 158004              Sabah                Keningau    153200.0
# 158403              Sabah            Kinabatangan    138100.0
# 158802              Sabah              Kota Belud    108300.0
# 159201              Sabah           Kota Kinabalu    500800.0
# 159600              Sabah             Kota Marudu     71100.0
# 159999              Sabah             Kuala Penyu     23700.0
# 160398              Sabah                   Kudat     87300.0
# 160797              Sabah                   Kunak     67800.0
# 161196              Sabah              Lahad Datu    226900.0
# 161595              Sabah                 Nabawan     29200.0
# 161994              Sabah                   Papar    152600.0
# 162393              Sabah               Penampang    163200.0
# 162792              Sabah                   Pitas     37300.0
# 163191              Sabah                 Putatan     69200.0
# 163590              Sabah                   Ranau     86300.0
# 163989              Sabah                Sandakan    435300.0
# 164388              Sabah                Semporna    165400.0
# 164787              Sabah                Sipitang     38100.0
# 165186              Sabah                Tambunan     32100.0
# 165585              Sabah                   Tawau    369600.0
# 165984              Sabah                 Telupid     28900.0
# 166383              Sabah                   Tenom     52000.0
# 166782              Sabah                  Tongod     42200.0
# 167181              Sabah                  Tuaran    137100.0
# 167580            Sarawak                 Asajaya     34100.0
# 167979            Sarawak                     Bau     53100.0
# 168378            Sarawak                  Belaga     22600.0
# 168777            Sarawak                  Beluru     28000.0
# 169176            Sarawak                  Betong     36500.0
# 169575            Sarawak                 Bintulu    179700.0
# 169974            Sarawak            Bukit Mabong     10400.0
# 170373            Sarawak                   Dalat     21200.0
# 170772            Sarawak                    Daro     19600.0
# 171171            Sarawak                   Julau     15400.0
# 171570            Sarawak                  Kabong     18600.0
# 171969            Sarawak                 Kanowit     24600.0
# 172368            Sarawak                   Kapit     36200.0
# 172767            Sarawak                 Kuching    615800.0
# 173166            Sarawak                   Lawas     37200.0
# 173565            Sarawak                 Limbang     45600.0
# 173964            Sarawak              Lubok Antu     24600.0
# 174363            Sarawak                   Lundu     33800.0
# 174762            Sarawak                Maradong     20500.0
# 175161            Sarawak                  Marudi     18800.0
# 175560            Sarawak                    Matu     16400.0
# 175959            Sarawak                    Miri    251200.0
# 176358            Sarawak                   Mukah     42500.0
# 176757            Sarawak                   Pakan     15600.0
# 177156            Sarawak                    Pusa     19700.0
# 177555            Sarawak               Samarahan    133500.0
# 177954            Sarawak                 Saratok     23100.0
# 178353            Sarawak                 Sarikei     44400.0
# 178752            Sarawak                  Sebauh     29100.0
# 179151            Sarawak                Selangau     19900.0
# 179550            Sarawak                  Serian     86000.0
# 179949            Sarawak                    Sibu    249000.0
# 180348            Sarawak                Simunjan     36500.0
# 180747            Sarawak                    Song     10000.0
# 181146            Sarawak                Sri Aman     61100.0
# 181545            Sarawak                   Subis     56600.0
# 181944            Sarawak           Tanjung Manis      7900.0
# 182343            Sarawak                   Tatau     32000.0
# 182742            Sarawak                  Tebedu     25300.0
# 183141            Sarawak             Telang Usan     17400.0
# 183540           Selangor                  Gombak    950200.0
# 183939           Selangor                   Klang   1094100.0
# 184338           Selangor            Kuala Langat    314500.0
# 184737           Selangor          Kuala Selangor    287600.0
# 185136           Selangor                Petaling   2304800.0
# 185535           Selangor            Sabak Bernam    107900.0
# 185934           Selangor                  Sepang    331500.0
# 186333           Selangor              Ulu Langat   1413300.0
# 186732           Selangor            Ulu Selangor    246400.0
# 187131         Terengganu                   Besut    159300.0
# 187530         Terengganu                  Dungun    162500.0
# 187929         Terengganu         Hulu Terengganu     72300.0
# 188328         Terengganu                 Kemaman    221700.0
# 188727         Terengganu             Kuala Nerus    151100.0
# 189126         Terengganu        Kuala Terengganu    236700.0
# 189525         Terengganu                  Marang    121500.0
# 189924         Terengganu                   Setiu     61500.0
# 190323  W.P. Kuala Lumpur       W.P. Kuala Lumpur   1961200.0
# 190722        W.P. Labuan             W.P. Labuan     96900.0
# 191121     W.P. Putrajaya          W.P. Putrajaya    117000.0

# %%
#Preprocess the hospital data
hospital_counts = hospital_df.groupby(['State', 'City']).size().reset_index(name='num_hospitals')
hospital_counts.rename(columns={'City': 'district', 'State': 'state'}, inplace=True)
print(str(hospital_counts))
# Out:
#                  state           district  num_hospitals
# 0                Johor         Batu Pahat              1
# 1                Johor        Johor Bahru              3
# 2                Johor             Kluang              1
# 3                Johor        Kota Tinggi              1
# 4                Johor          Kulaijaya              1
# ..                 ...                ...            ...
# 127         Terengganu   Kuala Terengganu              1
# 128         Terengganu              Setiu              1
# 129  W.P. Kuala Lumpur  W.P. Kuala Lumpur              4
# 130        W.P. Labuan        W.P. Labuan              1
# 131     W.P. Putrajaya     W.P. Putrajaya              2
#
# [132 rows x 3 columns]

# %%
#Preprocess the clinic data
clinic_counts = clinic_df.groupby(['State', 'District']).size().reset_index(name='num_clinics')
clinic_counts.rename(columns={'State': 'state', 'District': 'district'}, inplace=True)

print(str(clinic_counts))
# Out:
#                  state            district  num_clinics
# 0                Johor   81900 Kota Tinggi            1
# 1                Johor          Batu Pahat           62
# 2                Johor  Jalan Hang Lekir 1            1
# 3                Johor         Johor Bahru           36
# 4                Johor              Kluang           29
# ..                 ...                 ...          ...
# 181         Terengganu              Marang           20
# 182         Terengganu               Setiu           17
# 183  W.P. Kuala Lumpur   W.P. Kuala Lumpur           24
# 184        W.P. Labuan         W.P. Labuan           12
# 185     W.P. Putrajaya      W.P. Putrajaya            4
#
# [186 rows x 3 columns]

# %%
# Preprocess hospital bed data
beds_df['date'] = pd.to_datetime(beds_df['date'], dayfirst=True)
latest_bed_year = beds_df['date'].dt.year.max()
beds_filtered = beds_df[beds_df['date'].dt.year == 2022]

# Only district-specific entries, remove 'All'
beds_filtered = beds_df[
    (beds_df['date'].dt.year == 2022) &
    (beds_df['type'].str.lower() == 'all') &
    (~beds_df['district'].str.lower().str.contains('all', na=False))
]
bed_summary = beds_filtered.groupby(['state', 'district'])['beds'].sum().reset_index()
bed_summary.rename(columns={'beds': 'hospital_beds'}, inplace=True)

print(bed_summary.to_string() , bed_summary.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 153 entries, 0 to 152
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   state          153 non-null    object
#  1   district       153 non-null    object
#  2   hospital_beds  153 non-null    int64
# dtypes: int64(1), object(2)
# memory usage: 3.7+ KB
#                  state                            district  hospital_beds
# 0                Johor                          Batu Pahat            610
# 1                Johor                         Johor Bahru           3042
# 2                Johor                              Kluang            382
# 3                Johor                         Kota Tinggi            158
# 4                Johor                           Kulaijaya             93
# 5                Johor                              Ledang             69
# 6                Johor                             Mersing             70
# 7                Johor                                Muar            575
# 8                Johor                             Pontian            120
# 9                Johor                             Segamat            314
# 10               Kedah                              Baling            115
# 11               Kedah                       Bandar Baharu              0
# 12               Kedah                          Kota Setar           1108
# 13               Kedah                          Kuala Muda            703
# 14               Kedah                         Kubang Pasu             91
# 15               Kedah                               Kulim            320
# 16               Kedah                            Langkawi            163
# 17               Kedah                        Padang Terap             80
# 18               Kedah                             Pendang              0
# 19               Kedah                          Pokok Sena              0
# 20               Kedah                                 Sik             93
# 21               Kedah                                 Yan             89
# 22            Kelantan                              Bachok              0
# 23            Kelantan                          Gua Musang             90
# 24            Kelantan                                Jeli             80
# 25            Kelantan                          Kota Bharu           1811
# 26            Kelantan                          Kuala Krai            424
# 27            Kelantan                             Machang             90
# 28            Kelantan                           Pasir Mas            120
# 29            Kelantan                         Pasir Puteh             90
# 30            Kelantan                         Tanah Merah            146
# 31            Kelantan                              Tumpat            119
# 32              Melaka                          Alor Gajah            106
# 33              Melaka                               Jasin            103
# 34              Melaka                       Melaka Tengah           1245
# 35     Negeri Sembilan                              Jelebu             76
# 36     Negeri Sembilan                              Jempol            108
# 37     Negeri Sembilan                         Kuala Pilah            314
# 38     Negeri Sembilan                        Port Dickson            116
# 39     Negeri Sembilan                              Rembau             76
# 40     Negeri Sembilan                            Seremban           1143
# 41     Negeri Sembilan                              Tampin            144
# 42              Pahang                             Bentong            152
# 43              Pahang                                Bera             40
# 44              Pahang                   Cameron Highlands             40
# 45              Pahang                            Jerantut             77
# 46              Pahang                             Kuantan           1176
# 47              Pahang                               Lipis            168
# 48              Pahang                               Maran             70
# 49              Pahang                               Pekan            110
# 50              Pahang                                Raub             89
# 51              Pahang                              Rompin            109
# 52              Pahang                            Temerloh            650
# 53               Perak               Batang Padang (Tapah)            350
# 54               Perak                         Hilir Perak            548
# 55               Perak                          Hulu Perak             75
# 56               Perak                              Kampar             68
# 57               Perak                              Kerian            100
# 58               Perak                        Kinta (Ipoh)           3354
# 59               Perak                       Kuala Kangsar            229
# 60               Perak            Larut & Matang (Taiping)            698
# 61               Perak                  Manjung (Sitiawan)            415
# 62               Perak                        Perak Tengah             50
# 63              Perlis                              Perlis            508
# 64        Pulau Pinang                          Barat Daya             81
# 65        Pulau Pinang              Seberang Perai Selatan            105
# 66        Pulau Pinang               Seberang Perai Tengah            655
# 67        Pulau Pinang  Seberang Perai Utara (Butterworth)            134
# 68        Pulau Pinang             Timur Laut (Georgetown)           1163
# 69               Sabah                            Beaufort            275
# 70               Sabah                             Beluran             52
# 71               Sabah                            Keningau            216
# 72               Sabah                        Kinabatangan             68
# 73               Sabah                          Kota Belud            172
# 74               Sabah                       Kota Kinabalu           2175
# 75               Sabah                         Kota Marudu             97
# 76               Sabah                          Kota Penyu             48
# 77               Sabah                               Kudat            180
# 78               Sabah                               Kunak             48
# 79               Sabah                          Lahad Datu            268
# 80               Sabah                             Nabawan              0
# 81               Sabah                               Papar             77
# 82               Sabah                           Penampang              0
# 83               Sabah                               Pitas             72
# 84               Sabah                             Putatan              0
# 85               Sabah                               Ranau            110
# 86               Sabah                            Sandakan            400
# 87               Sabah                            Semporna             70
# 88               Sabah                            Sipitang             93
# 89               Sabah                            Tambunan             49
# 90               Sabah                               Tawau            431
# 91               Sabah                             Telupid              0
# 92               Sabah                               Tenom             70
# 93               Sabah                              Tongad              0
# 94               Sabah                              Tuaran             82
# 95             Sarawak                             Asajaya              0
# 96             Sarawak                                 Bau             68
# 97             Sarawak                              Belaga              0
# 98             Sarawak                              Beluru              0
# 99             Sarawak                              Betong             48
# 100            Sarawak                             Bintulu            302
# 101            Sarawak                        Bukit Mabong              0
# 102            Sarawak                               Dalat              8
# 103            Sarawak                                Daro             46
# 104            Sarawak                               Julau              0
# 105            Sarawak                              Kabong              0
# 106            Sarawak                             Kanowit            100
# 107            Sarawak                               Kapit            134
# 108            Sarawak                             Kuching           1412
# 109            Sarawak                               Lawas             46
# 110            Sarawak                             Limbang            100
# 111            Sarawak                          Lubok Antu              0
# 112            Sarawak                               Lundu             46
# 113            Sarawak                              Marudi             54
# 114            Sarawak                                Matu              0
# 115            Sarawak                            Meradong              0
# 116            Sarawak                                Miri            349
# 117            Sarawak                               Mukah             80
# 118            Sarawak                               Pakan              0
# 119            Sarawak                                Pusa              0
# 120            Sarawak                           Samarahan            128
# 121            Sarawak                             Saratok            106
# 122            Sarawak                             Sarikei            212
# 123            Sarawak                              Sebauh              0
# 124            Sarawak                            Selangau              0
# 125            Sarawak                              Serian             84
# 126            Sarawak                                Sibu            662
# 127            Sarawak                            Simunjan             42
# 128            Sarawak                                Song              0
# 129            Sarawak                            Sri Aman             92
# 130            Sarawak                               Subis              0
# 131            Sarawak                       Tanjung Manis              0
# 132            Sarawak                               Tatau              0
# 133            Sarawak                              Tebedu              0
# 134           Selangor                     Gombak (Rawang)           3153
# 135           Selangor                 Hulu Langat (Bangi)           1087
# 136           Selangor                       Hulu Selangor            120
# 137           Selangor                               Klang           1261
# 138           Selangor                        Kuala Langat            196
# 139           Selangor                      Kuala Selangor            114
# 140           Selangor              Petaling (Subang Jaya)            490
# 141           Selangor                        Sabak Bernam             93
# 142           Selangor                              Sepang           1126
# 143         Terengganu                               Besut            140
# 144         Terengganu                              Dungun            100
# 145         Terengganu                     Hulu Terengganu             95
# 146         Terengganu                             Kemaman            164
# 147         Terengganu                    Kuala Terengganu           1155
# 148         Terengganu                              Marang              0
# 149         Terengganu                               Setiu             76
# 150  W.P. Kuala Lumpur                   W.P. Kuala Lumpur           4874
# 151        W.P. Labuan                         W.P. Labuan            122
# 152     W.P. Putrajaya                      W.P. Putrajaya            637 None

# %%
# Start with population (since it determines which districts exist)
merged = pop_summary.copy()

# Merge hospital beds
merged = merged.merge(bed_summary, on=['state', 'district'], how='left')

# Merge hospitals
merged = merged.merge(hospital_counts, on=['state', 'district'], how='left')

# Merge clinics
merged = merged.merge(clinic_counts, on=['state', 'district'], how='left')

# %%
merged.to_csv("district_health_summary.csv", index=False)
print(merged.head())
# Out:
#    state     district  population  hospital_beds  num_hospitals  num_clinics
# 0  Johor   Batu Pahat    497500.0          610.0            1.0         62.0
# 1  Johor  Johor Bahru   1723700.0         3042.0            3.0         36.0
# 2  Johor       Kluang    323500.0          382.0            1.0         29.0
# 3  Johor  Kota Tinggi    224900.0          158.0            1.0         42.0
# 4  Johor        Kulai    329200.0            NaN            NaN         14.0
